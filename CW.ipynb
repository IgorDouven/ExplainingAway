# %% [markdown]
# # Just noise?

# %% [markdown]
# ### Reanalyzing the data from Douven and Schupbach (2015) in light of Costello and Watts' (2016) proposal

# %%
using DataFrames, MixedModels

# %% [markdown]
# Import the data from Douven and Schupbach (2015):

# %%
data = readtable("data.csv");

# %% [markdown]
# Add difference in explanatory goodness as well as identifiers for the random effects (here we are considering the full random effects as justified by the design, following the advice of Barr et al. 2013; in Douven and Schupbach 2015 only participants served as random effects):

# %%
data[:diff] = Array{Float64}(data[:Judge_A] .- data[:Judge_B])
data[:id] = repeat(1:26, inner=10)
data[:item] = repeat(1:10, outer=26)
head(data)
# Out:
# 6×9 DataFrames.DataFrame. Omitted printing of 2 columns
# │ Row │ Judge_A │ Judge_B │ Post_AO    │ Post_BO  │ Post_AS │ Post_BS │ diff  │
# ├─────┼─────────┼─────────┼────────────┼──────────┼─────────┼─────────┼───────┤
# │ 1   │ -0.35   │ 0.5     │ 0.285714   │ 0.714286 │ 0.35    │ 0.65    │ -0.85 │
# │ 2   │ -0.6    │ 0.6     │ 0.130435   │ 0.869565 │ 0.2     │ 0.8     │ -1.2  │
# │ 3   │ -0.7    │ 0.7     │ 0.0495868  │ 0.950413 │ 0.14    │ 0.86    │ -1.4  │
# │ 4   │ -0.8    │ 0.75    │ 0.0163297  │ 0.98367  │ 0.12    │ 0.88    │ -1.55 │
# │ 5   │ -0.85   │ 0.77    │ 0.00472069 │ 0.995279 │ 0.08    │ 0.92    │ -1.62 │
# │ 6   │ -0.85   │ 0.77    │ 0.00939702 │ 0.990603 │ 0.1     │ 0.9     │ -1.62 │

# %% [markdown]
# Below the model that came out on top in Douven and Schupbach's analysis, MMOD:

# %%
form = @formula(Post_AS ~ Post_AO + diff + (Post_AO + diff | id) + (Post_AO + diff | item));

# %%
mm = lmm(form, data);

# %%
fit!(mm)
# Out:
# Linear mixed model fit by maximum likelihood
#  Formula: Post_AS ~ Post_AO + diff + ((Post_AO + diff) | id) + ((Post_AO + diff) | item)
#    logLik   -2 logLik     AIC        BIC
#   329.66781 -659.33562 -627.33562 -570.36471
#
# Variance components:
#               Column     Variance     Std.Dev.    Corr.
#  id       (Intercept)  0.0198144502 0.140763810
#           Post_AO      0.0912910704 0.302144122 -0.99
#           diff         0.0094713702 0.097320965  0.74 -0.77
#  item     (Intercept)  0.0006500329 0.025495742
#           Post_AO      0.0022200615 0.047117529 -0.97
#           diff         0.0001340888 0.011579672  0.41 -0.61
#  Residual              0.0028837816 0.053700853
#  Number of obs: 260; levels of grouping factors: 26, 10
#
#   Fixed-effects parameters:
#              Estimate Std.Error z value P(>|z|)
# (Intercept)  0.330241 0.0340706 9.69283  <1e-21
# Post_AO      0.396672 0.0710099 5.58615   <1e-7
# diff         0.121457 0.0249633 4.86542   <1e-5

# %% [markdown]
# Below the Bayesian model, MMO:

# %%
form₀ = @formula(Post_AS ~ Post_AO + (Post_AO | id) + (Post_AO | item));

# %%
mm₀ = lmm(form₀, data);

# %%
fit!(mm₀)
# Out:
# Linear mixed model fit by maximum likelihood
#  Formula: Post_AS ~ Post_AO + (Post_AO | id) + (Post_AO | item)
#    logLik   -2 logLik     AIC        BIC
#    284.5356  -569.0712  -551.0712  -519.0251
#
# Variance components:
#               Column     Variance     Std.Dev.    Corr.
#  id       (Intercept)  0.0123408709 0.111089473
#           Post_AO      0.0548479933 0.234196484 -0.95
#  item     (Intercept)  0.0007137262 0.026715654
#           Post_AO      0.0015934398 0.039917913 -0.97
#  Residual              0.0045279637 0.067290146
#  Number of obs: 260; levels of grouping factors: 26, 10
#
#   Fixed-effects parameters:
#              Estimate Std.Error z value P(>|z|)
# (Intercept)  0.212377 0.0261722 8.11461  <1e-15
# Post_AO      0.642234 0.0512126 12.5405  <1e-35

# %% [markdown]
# Finally, the model MMOAB:

# %%
form₁ = @formula(Post_AS ~ Post_AO + Judge_A + Judge_B + (Post_AO + Judge_A + Judge_B | id) + (Post_AO + Judge_A + Judge_B | item));

# %%
mm₁ = lmm(form₁, data);

# %%
fit!(mm₁)
# Out:
# Linear mixed model fit by maximum likelihood
#  Formula: Post_AS ~ Post_AO + Judge_A + Judge_B + ((Post_AO + Judge_A + Judge_B) | id) + ((Post_AO + Judge_A + Judge_B) | item)
#    logLik   -2 logLik     AIC        BIC
#   335.91849 -671.83699 -621.83699 -532.81995
#
# Variance components:
#               Column      Variance     Std.Dev.    Corr.
#  id       (Intercept)  0.02011490904 0.141827039
#           Post_AO      0.08863836838 0.297721965 -0.99
#           Judge_A      0.01182864701 0.108759584  0.77 -0.76
#           Judge_B      0.00683843129 0.082694808 -0.83  0.82 -0.99
#  item     (Intercept)  0.00065499613 0.025592892
#           Post_AO      0.00287698638 0.053637546 -1.00
#           Judge_A      0.00314539596 0.056083830  0.62 -0.62
#           Judge_B      0.00063175922 0.025134821  0.41 -0.41  0.97
#  Residual              0.00261269872 0.051114565
#  Number of obs: 260; levels of grouping factors: 26, 10
#
#   Fixed-effects parameters:
#               Estimate Std.Error  z value P(>|z|)
# (Intercept)   0.321204 0.0345961  9.28438  <1e-19
# Post_AO       0.416092  0.070705   5.8849   <1e-8
# Judge_A       0.109684 0.0350185  3.13218  0.0017
# Judge_B      -0.117037 0.0269285 -4.34623   <1e-4

# %% [markdown]
# Likelihood ratio tests

# %%
MixedModels.lrt(mm₀, mm)
# Out:
# 2×4 DataFrames.DataFrame
# │ Row │ Df │ Deviance │ Chisq   │ pval        │
# ├─────┼────┼──────────┼─────────┼─────────────┤
# │ 1   │ 9  │ -569.071 │ NaN     │ NaN         │
# │ 2   │ 16 │ -659.336 │ 90.2644 │ 1.09184e-16 │

# %%
MixedModels.lrt(mm₀, mm₁)
# Out:
# 2×4 DataFrames.DataFrame
# │ Row │ Df │ Deviance │ Chisq   │ pval        │
# ├─────┼────┼──────────┼─────────┼─────────────┤
# │ 1   │ 9  │ -569.071 │ NaN     │ NaN         │
# │ 2   │ 25 │ -671.837 │ 102.766 │ 1.04745e-14 │

# %% [markdown]
# We can answer the question of whether Costello and Watts' proposal can account for Douven and Schupbach's findings by trying to predict the subjective updated probabilities reported by Douven and Schupbach not by the objective conditional probabilities but instead by the 'noisy' version of that predictor, transformed according to the formula given by Costello and Watts. The following first defines a function that takes Costello and Watts' error parameter *d* as input and outputs the transformed predictor for the given value of *d*. The function is based on Eq. 17 in Costello and Watts (2018), according to which
# $$
# \Pr\nolimits_*(A\,|\,B) \:\: = \:\: \frac{(1-2d)^2\Pr(A\wedge B) + d(1-2d)\bigl(\Pr(A) + \Pr(B)\bigr) + d^2}{(1-2d)\Pr(B) + d},
# $$
# where $\Pr_*(A\,|\,B)$ is the noisy estimate of the probability of $A$ conditional on $B$, and with the noise parameter $d\in[0,.5)$. Notice that if $d=0$, indicating that there is no noise, then
# $$
# \Pr\nolimits_*(A\,|\,B)  \:\: = \:\: \frac{\Pr(A\wedge B)}{\Pr(B)} \:\: = \:\: \Pr(A\,|\,B).
# $$
# Then we fit for *d* going from 0 to .5, in small increments, mixed models like the ones above except that the new models have the noisy objective probabilities, rather than the unnoisy ones, as predictor. We look whether for at least one value of *d* the correspondig Bayesian model does best, or whether explanatory considerations do still make a significant contribution to model fit even when noise is taken into account.
#
# First calculate the probabilities needed to perform the Costello and Watts transformation:

# %%
data1 = copy(data)

ProbEvA = Array{Float64}(10, 26)
ProbEvB = Array{Float64}(10, 26)

for i in 1:26
    
    Pr = vcat(0.5, data1[:Post_AO][(i * 10 - 9):(i * 10)])

    for j in 1:10
        Pr[j + 1] < Pr[j] ? (ProbEvA[j, i], ProbEvB[j, i]) = (0.25, 0.625) : (ProbEvA[j, i], ProbEvB[j, i]) = (0.75, 0.375)
    end

end

data1[:ProbEv] = mean(hcat(cumprod(ProbEvA, 1)[:], cumprod(ProbEvB, 1)[:]), 2)[:]
data1[:HA_Ev] = data1[:Post_AO] .* data1[:ProbEv];

# %%
head(data1)
# Out:
# 6×11 DataFrames.DataFrame. Omitted printing of 4 columns
# │ Row │ Judge_A │ Judge_B │ Post_AO    │ Post_BO  │ Post_AS │ Post_BS │ diff  │
# ├─────┼─────────┼─────────┼────────────┼──────────┼─────────┼─────────┼───────┤
# │ 1   │ -0.35   │ 0.5     │ 0.285714   │ 0.714286 │ 0.35    │ 0.65    │ -0.85 │
# │ 2   │ -0.6    │ 0.6     │ 0.130435   │ 0.869565 │ 0.2     │ 0.8     │ -1.2  │
# │ 3   │ -0.7    │ 0.7     │ 0.0495868  │ 0.950413 │ 0.14    │ 0.86    │ -1.4  │
# │ 4   │ -0.8    │ 0.75    │ 0.0163297  │ 0.98367  │ 0.12    │ 0.88    │ -1.55 │
# │ 5   │ -0.85   │ 0.77    │ 0.00472069 │ 0.995279 │ 0.08    │ 0.92    │ -1.62 │
# │ 6   │ -0.85   │ 0.77    │ 0.00939702 │ 0.990603 │ 0.1     │ 0.9     │ -1.62 │

# %% [markdown]
# The following function calculates AIC values for the Bayesian model (with 'noisified' objective probabilities as predictor), the model with noisified objective probabilities and judgments of explanatory goodness as predictors, and the model with noisified objective probabilities and *difference* in explanatory goodness as predictors, for a range of possible noisifications:

# %%
function aic_vals(d)

    data1[:Prob_noise] = ((1-2d)^2 .* data1[:HA_Ev] .+ 
        (d-2d^2) .* (0.5 .+ data1[:ProbEv]) .+ d^2) ./ ((1-2d) .* data1[:ProbEv] .+ d)

    BAY = MixedModels.aic(fit!(lmm(@formula(Post_AS ~ Prob_noise + (1 + Prob_noise | id) + (1 + Prob_noise | item)), data1)))
            
    EXPL = MixedModels.aic(fit!(lmm(@formula(Post_AS ~ Prob_noise + Judge_A + Judge_B + (1 + Prob_noise + Judge_A + Judge_B | id) +
                                (1 + Prob_noise + Judge_A + Judge_B | item)), data1)))

    DIFF = MixedModels.aic(fit!(lmm(@formula(Post_AS ~ Prob_noise + diff + (1 + Prob_noise + diff | id) + (1 + Prob_noise + diff | item)), data1)))
    
    return vcat(BAY, EXPL, DIFF)

end
# Out:
# aic_vals (generic function with 1 method)

# %%
aicVals = Array{Float64, 2}(100, 3)

for i in 1:100
    aicVals[i,:] = aic_vals(collect(0.0:0.005:0.495)[i])
end

# %%
AV = DataFrame( AIC = aicVals[:],
                d_val = repeat(collect(0.000:0.005:0.495), outer=3),
                Predictors = repeat(["<i>f</i>(O, <i>d</i>)", "<i>f</i>(O, <i>d</i>)AB", "<i>f</i>(O, <i>d</i>)D"], inner=100));

# %% [markdown]
# Visualize the outcomes:

# %%
using Gadfly, Fontconfig, Cairo

# %%
using Colors

function gen_brew_colors(n) # to create your own colors, here based on one of the brewer series
    cs = distinguishable_colors(n, 
        [colorant"#66c2a5", colorant"#fc8d62", colorant"#8da0cb", colorant"#e78ac3", 
            colorant"#a6d854", colorant"#ffd92f", colorant"#e5c494", colorant"#b3b3b3"],
        lchoices=Float64[58, 45, 72.5, 90],
        transform=c -> deuteranopic(c, 0.1),
        cchoices=Float64[20,40],
        hchoices=[75,51,35,120,180,210,270,310]
    )
    convert(Vector{Color}, cs)
end

set_default_plot_size(8inch, 8inch/golden)

# %%
CW = plot(AV, x=:d_val, y=:AIC, color=:Predictors, Geom.point,
    Guide.ylabel("AIC value"),
    Guide.xlabel("<i>d</i>"),
    Scale.color_discrete_manual(gen_brew_colors(3)...),
    Theme(point_size=2.5pt, minor_label_font_size=10pt,
        major_label_font_size=14pt,
        minor_label_color=colorant"black",
        major_label_color=colorant"black",
        key_title_font_size=13pt,
        key_label_font_size=11pt,
        key_label_color=colorant"black",
        key_title_color=colorant"black",
        highlight_width=0.25pt))
# Out:
# Plot(...)

# %%
draw(PDF("CW.pdf", 8inch, 8inch/golden, dpi=600), CW);

# %%
using RCall

# %%
R"""
library(afex)
library(sjstats)
library(BayesFactor)
"""

@rput data;

# %%
R"lmBF(Post_AS ~ Post_AO + Judge_A + Judge_B, whichRandom = c('id', 'item'), data=data)"
# Out:
# RCall.RObject{RCall.S4Sxp}
# Bayes factor analysis
# --------------
# [1] Post_AO + Judge_A + Judge_B : 3.003277e+121 ±0%
#
# Against denominator:
#   Intercept only
# ---
# Bayes factor type: BFlinearModel, JZS

# %%
R"lmBF(Post_AS ~ Post_AO, whichRandom = c('id', 'item'), data=data)"
# Out:
# RCall.RObject{RCall.S4Sxp}
# Bayes factor analysis
# --------------
# [1] Post_AO : 5.61909e+97 ±0.01%
#
# Against denominator:
#   Intercept only
# ---
# Bayes factor type: BFlinearModel, JZS

# %%
R"lmBF(Post_AS ~ Post_AO + diff, whichRandom = c('id', 'item'), data=data)"
# Out:
# RCall.RObject{RCall.S4Sxp}
# Bayes factor analysis
# --------------
# [1] Post_AO + diff : 6.24216e+122 ±0%
#
# Against denominator:
#   Intercept only
# ---
# Bayes factor type: BFlinearModel, JZS

# %%
R"r2(lmer(Post_AS ~ Post_AO + (1 + Post_AO | id) + (1 + Post_AO | item), data=data, control=lmerControl(optCtrl=list(maxfun=1e6))))"
# Out:
# RCall.RObject{RCall.VecSxp}
#     R-squared: 0.9480
# Omega-squared: 0.9479

# %%
R"r2(lmer(Post_AS ~ Post_AO + Judge_A + Judge_B + (1 + Post_AO + Judge_A + Judge_B || id) + (1 + Post_AO + Judge_A + Judge_B || item), data=data, control=lmerControl(optCtrl=list(maxfun=1e8))))"
# Out:
# RCall.RObject{RCall.VecSxp}
#     R-squared: 0.9676
# Omega-squared: 0.9676

# %%
R"r2(lmer(Post_AS ~ Post_AO + diff + (1 + Post_AO + diff || id) + (1 + Post_AO + diff || item), data=data, control=lmerControl(optCtrl=list(maxfun=1e6))))"
# Out:
# RCall.RObject{RCall.VecSxp}
#     R-squared: 0.9631
# Omega-squared: 0.9631
